# %%
import pandas as pd
df = pd.read_csv("/Users/lucaslu/Lucas/Code Repositories/PY191_lab/unh.csv")
df.drop(df.index[0], inplace=True)
print(df)
# Out:
#            Date    Year  Month   Day    Weekday  Week_Number Year_Week  \
# 1    2025-06-30  2025.0    6.0  30.0     Monday         26.0   2025-26
# 2    2025-07-01  2025.0    7.0   1.0    Tuesday         26.0   2025-26
# 3    2025-07-02  2025.0    7.0   2.0  Wednesday         26.0   2025-26
# 4    2025-07-03  2025.0    7.0   3.0   Thursday         26.0   2025-26
# 5    2025-07-07  2025.0    7.0   7.0     Monday         27.0   2025-27
# ..          ...     ...    ...   ...        ...          ...       ...
# 247  2026-06-23  2026.0    6.0  23.0    Tuesday         25.0   2026-25
# 248  2026-06-24  2026.0    6.0  24.0  Wednesday         25.0   2026-25
# 249  2026-06-25  2026.0    6.0  25.0   Thursday         25.0   2026-25
# 250  2026-06-26  2026.0    6.0  26.0     Friday         25.0   2026-25
# 251  2026-06-29  2026.0    6.0  29.0     Monday         26.0   2026-26
#
#        Open    High     Low   Close    Volume    Return    Short_MA   Long_MA
# 1    300.94  304.23  298.35  303.83  10074100  0.000000  303.830000  303.8300
# 2    303.83  318.03  302.97  317.63  17865500  0.045421  310.730000  310.7300
# 3    312.37  314.01  298.44  299.54  18177200 -0.056969  307.000000  307.0000
# 4    301.76  304.11  300.19   300.5   6161100  0.003219  305.375000  305.3750
# 5    299.97  300.56  293.34  295.79   9031200 -0.015686  303.458000  303.4580
# ..      ...     ...     ...     ...       ...       ...         ...       ...
# 247  409.52   409.9  402.84  409.25   6675900  0.006319  402.207143  374.8974
# 248  410.54  413.43   400.0   405.8   6858800 -0.008430  404.417143  376.7890
# 249  406.65  417.58  406.65  415.53   6014400  0.023977  405.939286  378.8514
# 250  416.16  427.93  416.16  427.89  10588200  0.029745  408.131429  381.1638
# 251  426.53   426.7  415.81  419.82   5167400 -0.018860  409.242857  383.2682
#
# [251 rows x 15 columns]

# %%
mon = df[df["Weekday"] == "Monday"]["Return"].mean()
tue = df[df["Weekday"] == "Tuesday"]["Return"].mean()
wed = df[df["Weekday"] == "Wednesday"]["Return"].mean()
thur = df[df["Weekday"] == "Thursday"]["Return"].mean()
fri = df[df["Weekday"] == "Friday"]["Return"].mean()

print(
f"""Monday: {mon}
Tuesday: {tue}
Wednesday: {wed}
Thursday {thur}
Friday: {fri}
"""
)
# Out:
# Monday: 0.0003325640006168653
# Tuesday: 0.0019293476561012231
# Wednesday: 0.003121951789561755
# Thursday -0.0026628640755205174
# Friday: 0.005253911632286902

# %%
last_digit = df["Close"].str[-1].astype(int)
last_digit.hist(bins = range(11))
# Out:
# <Axes: >
